# %%
import pandas as pd
df=pd.read_csv('Dataset_sensors.csv')
df
# Out:
#       weather_temperature  weather_humidity  solar_radiation  soil_moisture  \
# 0                    23.7              57.7               35          59.66
# 1                    23.4              57.2               33          56.85
# 2                    23.4              56.9               32          54.82
# 3                    23.5              56.8               33          53.24
# 4                    23.7              58.0               32          52.16
# ...                   ...               ...              ...            ...
# 3079                 25.8              50.4               70          47.47
# 3080                 25.8              50.3               71          47.57
# 3081                 25.8              50.3               71          47.81
# 3082                 25.8              50.4               70          47.96
# 3083                 25.7              50.5               71          48.03
#
#       soil_temperature  Unnamed: 5
# ...

# %%
import matplotlib.pyplot as plt

# Plotting histogram
plt.hist(df['solar_radiation'], bins=20, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('solar_radiation')
plt.ylabel('Frequency')
plt.title('solar_radiation')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting histogram
plt.hist(df['weather_temperature'], bins=20, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('weather_temperature')
plt.ylabel('Frequency')
plt.title('weather_temperature')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting histogram
plt.hist(df['weather_humidity'], bins=20, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('weather_humidity')
plt.ylabel('Frequency')
plt.title('weather_humidity')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting histogram
plt.hist(df['soil_moisture'], bins=20, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('soil_moisture')
plt.ylabel('Frequency')
plt.title('soil_moisture')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting histogram
plt.hist(df['soil_temperature'], bins=20, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('soil_temperature')
plt.ylabel('Frequency')
plt.title('soil_temperature')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot for weather_temperature vs weather_humidity
plt.scatter(df['weather_temperature'], df['weather_humidity'], s=20)
plt.xlabel('Weather Temperature')
plt.ylabel('Weather Humidity')
plt.title('Weather Temperature vs Humidity')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_temperature'].corr(df['weather_humidity'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.6483755815405174

# %%
# Scatter plot for weather_temperature vs solar_radiation
plt.scatter(df['weather_temperature'], df['solar_radiation'], s=20)
plt.xlabel('Weather Temperature')
plt.ylabel('Solar Radiation')
plt.title('Weather Temperature vs Solar Radiation')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_temperature'].corr(df['solar_radiation'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.07406356636669828

# %%
# Scatter plot for weather_temperature vs soil_moisture
plt.scatter(df['weather_temperature'], df['soil_moisture'], s=20)
plt.xlabel('Weather Temperature')
plt.ylabel('Soil Moisture')
plt.title('Weather Temperature vs Soil Moisture')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_temperature'].corr(df['soil_moisture'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.03448523110632438

# %%
# Scatter plot for weather_temperature vs soil_temperature
plt.scatter(df['weather_temperature'], df['soil_temperature'], s=20)
plt.xlabel('Weather Temperature')
plt.ylabel('Soil Temperature')
plt.title('Weather Temperature vs Soil Temperature')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_temperature'].corr(df['soil_temperature'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# 0.9920305133830556

# %%
# Scatter plot for weather_humidity vs solar_radiation
plt.scatter(df['weather_humidity'], df['solar_radiation'], s=20)
plt.xlabel('Weather Humidity')
plt.ylabel('Solar Radiation')
plt.title('Weather Humidity vs Solar Radiation')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_humidity'].corr(df['solar_radiation'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.2950300152343349

# %%
# Scatter plot for weather_humidity vs soil_moisture
plt.scatter(df['weather_humidity'], df['soil_moisture'], s=20)
plt.xlabel('Weather Humidity')
plt.ylabel('Soil Moisture')
plt.title('Weather Humidity vs Soil Moisture')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_humidity'].corr(df['soil_moisture'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# 0.03445940616061481

# %%
# Scatter plot for weather_humidity vs soil_temperature
plt.scatter(df['weather_humidity'], df['soil_temperature'], s=20)
plt.xlabel('Weather Humidity')
plt.ylabel('Soil Temperature')
plt.title('Weather Humidity vs Soil Temperature')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['weather_humidity'].corr(df['soil_temperature'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.6245805573456832

# %%
# Scatter plot for solar_radiation vs soil_moisture
plt.scatter(df['solar_radiation'], df['soil_moisture'], s=20)
plt.xlabel('Solar Radiation')
plt.ylabel('Soil Moisture')
plt.title('Solar Radiation vs Soil Moisture')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['solar_radiation'].corr(df['soil_moisture'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.0736550696915963

# %%
# Scatter plot for solar_radiation vs soil_temperature
plt.scatter(df['solar_radiation'], df['soil_temperature'], s=20)
plt.xlabel('Solar Radiation')
plt.ylabel('Soil Temperature')
plt.title('Solar Radiation vs Soil Temperature')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['solar_radiation'].corr(df['soil_temperature'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.055851492622666275

# %%
# Scatter plot for soil_moisture vs soil_temperature
plt.scatter(df['soil_moisture'], df['soil_temperature'], s=20)
plt.xlabel('Soil Moisture')
plt.ylabel('Soil Temperature')
plt.title('Soil Moisture vs Soil Temperature')
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df['soil_moisture'].corr(df['soil_temperature'])

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# -0.041796818289586125
